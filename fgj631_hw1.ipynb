# %% [markdown]
# String

# %%
intro_string = 'Welcome to Python Programming'
print(intro_string)
# Out:
# Welcome to Python Programming

# %%
intro_string[11:16]
# Out:
# 'Pytho'

# %%
intro_string[-5:]
# Out:
# 'mming'

# %%
mark_string = '!!!'
print(intro_string + mark_string)
# Out:
# Welcome to Python Programming!!!

# %% [markdown]
# List

# %%
list = []
list.extend([1, 2, 3, 4])
list
# Out:
# [1, 2, 3, 4]

# %%
list.append((5,6))

# %%
list
# Out:
# [1, 2, 3, 4, (5, 6)]

# %%
list.append(['perfect', 'wonderful'])

# %%
list
# Out:
# [1, 2, 3, 4, (5, 6), ['perfect', 'wonderful']]

# %%
list_2 = [[7, 8], [9, 10]]
list + list_2
# Out:
# [1, 2, 3, 4, (5, 6), ['perfect', 'wonderful'], [7, 8], [9, 10]]

# %%
list.extend([8.5, 7, 'code', 'software'])
list
# Out:
# [1, 2, 3, 4, (5, 6), ['perfect', 'wonderful'], 8.5, 7, 'code', 'software']

# %%
list[-5:]
# Out:
# [['perfect', 'wonderful'], 8.5, 7, 'code', 'software']

# %%
del list[3:6]
list
# Out:
# [1, 2, 3, 8.5, 7, 'code', 'software']

# %% [markdown]
# Tuple

# %%
Truple_list= [1, 2, 3, 4]
Tuple1 = tuple(Truple_list)

# %%
Tuple2 = ('Python', 'for', 'kids' )
Tuple2
# Out:
# ('Python', 'for', 'kids')

# %%
Tuple1 = (Tuple1 + Tuple2)
Tuple1
# Out:
# (1, 2, 3, 4, 'Python', 'for', 'kids')

# %%
Tuple1[3:]
# Out:
# (4, 'Python', 'for', 'kids')

# %% [markdown]
# Dictionary

# %%
Dict = {}

# %%
Dict[0] = 'Python'
Dict[1] = 'Programming'
Dict[2] = 'Funny'
Dict
# Out:
# {0: 'Python', 1: 'Programming', 2: 'Funny'}

# %%
Dict[1] = 'is very'
Dict
# Out:
# {0: 'Python', 1: 'is very', 2: 'Funny'}

# %%
Dict.keys()
# Out:
# dict_keys([0, 1, 2])

# %%
Dict.values()
# Out:
# dict_values(['Python', 'is very', 'Funny'])

# %%
del Dict[2]
Dict
# Out:
# {0: 'Python', 1: 'is very'}

# %%
key_exists = 2 in Dict
key_exists
# Out:
# False

# %%
values_list = []
for key in Dict:
    values_list.append(Dict[key])

# %%
values_list
# Out:
# ['Python', 'is very']
